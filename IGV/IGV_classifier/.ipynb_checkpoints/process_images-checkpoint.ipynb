# %%
from PIL import Image
import numpy as np
import os
import re
from utils import process_one_image

# %% [markdown]
# we removed the black space and inner white space in the IGV variant snapshot

# %% [markdown]
# # snp image before processing

# %%
image_adr = 'data/snp/sample.1.1465447.png'
n_block = 2
new_width, new_height = 200, 200
img = Image.open(image_adr)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=3750x1014 at 0x10FF02850>

# %% [markdown]
# ## snp image after processing

# %%
img = process_one_image(image_adr, n_block, new_width, new_height)
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x10FF02A90>

# %% [markdown]
# #  deletion image before processing

# %%
image_adr = 'data/deletion/sample.10.17715298.png'
n_block = 2
new_width, new_height = 200, 200
img = Image.open(image_adr)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=3830x1222 at 0x10FF02E50>

# %% [markdown]
# # deletion image after processing

# %%
img = process_one_image(image_adr, n_block, new_width, new_height)
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x10FF02DD0>

# %% [markdown]
# # insertion image before processing

# %%
image_adr = 'data/insertion/sample.1.245134187.png'
n_block = 2
new_width, new_height = 200, 200
img = Image.open(image_adr)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=3830x1221 at 0x10FF1B090>

# %% [markdown]
# # insertion image after processing
#
# ## we modify the insertion bar into a snp like line

# %%
img = process_one_image(image_adr, n_block, new_width, new_height)
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x10FF02210>

# %% [markdown]
# # failed image before processing

# %%
image_adr = 'data/fail/sample.2.114737231.png'
n_block = 2
new_width, new_height = 200, 200
img = Image.open(image_adr)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=3750x1219 at 0x10FF1B150>

# %% [markdown]
# # failed image after processing

# %%
img = process_one_image(image_adr, n_block, new_width, new_height)
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x10FF02C90>
